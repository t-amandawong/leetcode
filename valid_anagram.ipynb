# %% [markdown]
# # Problem

# %% [markdown]
# Links: [Leetcode](https://leetcode.com/problems/valid-anagram/description/), [Neetcode](https://neetcode.io/solutions/valid-anagram)
#
# Given two strings `s` and `t`, return `true` if `t` is an anagram of `s`, and `false` otherwise.

# %% [markdown]
# # Solution

# %% [markdown]
# ## Edge Case(s):
# - `s` & `t` do not have matching lengths : false

# %% [markdown]
# ## Approach:
#
# My initial approach would be to make sorted lists of each of the strings, and see if they match.

# %% [markdown]
# ## Complexity:
# - Time Complexity: O(n + m)
# - Space Complexity: O(n + m)

# %% [markdown]
# ## Code:

# %%
class Solution(object):
    def isAnagram(self, s, t):
        """
        :type s: str
        :type t: str
        :rtype: bool
        """
        return sorted(s) == sorted(t)

# %% [markdown]
# # Test

# %%
solution = Solution()

s = "nagaram"
t = "anagram"
print(solution.isAnagram(s, t))
