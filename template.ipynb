# %% [markdown]
# # Problem

# %% [markdown]
# Links:

# %% [markdown]
# # Solution

# %% [markdown]
# ## Edge Case(s):
# -
# -
# -

# %% [markdown]
# ## Approach:

# %% [markdown]
# ## Complexity:
# - Time Complexity:
# - Space Complexity:

# %% [markdown]
# ## Code:

# %%
Class Solution(object):
    def example:

# %% [markdown]
# # Test
