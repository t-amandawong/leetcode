# %% [markdown]
# # Problem

# %% [markdown]
# Links:

# %% [markdown]
# # Solution

# %% [markdown]
# ## Edge Case(s):
# -
# -
# -

# %% [markdown]
# ## Approach:

# %% [markdown]
# ## Complexity:
# - Time Complexity:
# - Space Complexity:

# %% [markdown]
# ## Code:

# %%
class Solution(object):
    def example(self):
        return

# %% [markdown]
# # Test

# %%
solution = Solution()
